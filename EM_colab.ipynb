# %%
# load
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Generate molecules
# %cd /content/drive/MyDrive/Colab Notebooks/EMGNN/RNN_generation
# !python launcher_of_clm.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/EMGNN/RNN_generation
# [WARNING] matplotlib use Agg.
# Structure of model:
# NNLM(
#   (lstm): LSTM(99, 256, num_layers=3, batch_first=True, dropout=0.2)
#   (linear): Linear(in_features=256, out_features=99, bias=True)
# )
# Number of parameters: 1443683
# Load model: ./record/gutl-0050-12.2942.pth
# Sampling ...
# Sampling ...
# /content/drive/MyDrive/Colab Notebooks/EMGNN/RNN_generation/utils/builder.py:121: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(output)
# Sampling Finished !
# Checking ...
# [09:11:22] SMILES Parse Error: unclosed ring for input: '[H]C(N=[N+]=[N-])CN=C=C1[N+]([O-])=O'
# [09:11:22] SMILES Parse Error: unclosed ring for input: 'NC1=C(C(NN)=C2N=NN=C2N)N'
# [09:11:22] SMILES Parse Error: unclosed ring for input: 'NC1=C(N=C(N)C2=C3C([N+]([O-])=O)=C(C([N+]([O-])=O)=NN3)N3C2=NN=C3N)[N+]([O-])=O'
# [09:11:22] Explicit valence for atom # 25 N, 5, is greater than permitted
# [09:11:22] SMILES Parse Error: unclosed ring for input: 'OC1=NN=NC2=C1C([N+](=O)[O-])([N+]([O-])=O)[N+]([O-])=O'
# [09:11:22] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])C(C1=C(C([N+]([O-])=O)=NN1N)N2)=CN2N=NC([N+]([O-])=O)=C2[N+]([O-])=O'
# [09:11:22] Explicit valence for atom # 7 N, 4, is greater than permitted
# [09:11:22] Explicit valence for atom # 12 N, 4, is greater than permitted
# [09:11:22] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])C1=NN2C(C3=NON=C3N=NN4C(N)=NN=C4N2)N=N3'
# [09:11:22] SMILES Parse Error: unclosed ring for input: 'O=C(C=C1N2N=C(C([N+]([O-])=O)=C2C3=NOC(C4=NC(C5=NN(C([N+]([O-])=O)=N5)C5NN=C(N5)C5=NO[N+]([O-])=C4[N+]([O-])=O)=N3)=N2)=O)[O-]'
# [09:11:22] Explicit valence for atom # 17 N, 5, is greater than permitted
# [09:11:22] SMILES Parse Error: unclosed ring for input: '[H]C(O[N+]([O-])=N1CC2(N=N1)C3N=N1)[N+]([O-])=O'
# Checking Finished !
# Sampling Finished !
# Sample:50, Valid:38, Unique:38, Novel:28

# %%
#Predict BDE values
# %cd /content/drive/MyDrive/Colab Notebooks/EMGNN/BDE_model
! pip install rdkit

! python predict.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/EMGNN/BDE_model
# Collecting rdkit
#   Downloading rdkit-2025.3.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# Downloading rdkit-2025.3.2-cp311-cp311-manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 22.7 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.3.2
# /content/drive/MyDrive/Colab Notebooks/EMGNN/BDE_model/predict.py:71: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if j is not 0 :
# r2: 0.9800031922970055
# MAE: 7.790115390248593
# RMSE: 11.605921618987654
#
#
# r2: 0.9726673651133759
# MAE: 8.717689306130852
# RMSE: 13.211425957569741
#
#
# r2: 0.9765142692942201
# MAE: 8.595232432862822
# RMSE: 11.998909477380446
#
#
# r2: 0.9595264964626056
# MAE: 10.284834077719998
# RMSE: 17.026212086760232
#
#
# r2: 0.9625625043901808
# MAE: 10.34238779972696
# RMSE: 17.38128300252023
#
#
# r2: 0.9778187009967658
# MAE: 8.32170344820367
# RMSE: 12.609252077352656
#
#
# r2: 0.9632860589769209
# MAE: 8.20787913643172
# RMSE: 14.9084665221487
#
#
# r2: 0.9721408554844315
# MAE: 8.477921775659158
# RMSE: 13.055332729772983
#
#
# r2: 0.9542629088437133
# MAE: 9.546749286860571
# RMSE: 16.17580366084525
#
#
# r2: 0.9775658658527795
# MAE: 8.564573017497638
# RMSE: 12.537863212486142
#
#
# r2: 0.9737496828931577
# MAE: 9.811760811779205
# RMSE: 13.776304098681134
#
#
# r2: 0.9739849569829494
# MAE: 9.514669455663356
# RMSE: 14.340024883127466
#
#
# r2: 0.9689249393722305
# MAE: 8.75338154558961
# RMSE: 14.235163592993315
#
#
# r2: 0.970088875290393
# MAE: 8.402102521906098
# RMSE: 14.489037910296329
#
#
# r2: 0.9705742032607407
# MAE: 8.592568730732463
# RMSE: 14.344902498909168
#
#
# r2: 0.9729016931453687
# MAE: 8.109803086828311
# RMSE: 12.868050758138617
#
#
# r2: 0.976046370512338
# MAE: 8.92037993491483
# RMSE: 12.960773036850679
#
#
# r2: 0.969851355512636
# MAE: 9.321940809025595
# RMSE: 14.35376978915374
#
#
# r2: 0.9714893456863396
# MAE: 9.482036720379933
# RMSE: 14.212709002649673
#
#
# r2: 0.971188697196761
# MAE: 7.9832632381153035
# RMSE: 12.614692728007183
#
#
# r2_test: [0.9800031922970055, 0.9726673651133759, 0.9765142692942201, 0.9595264964626056, 0.9625625043901808, 0.9778187009967658, 0.9632860589769209, 0.9721408554844315, 0.9542629088437133, 0.9775658658527795, 0.9737496828931577, 0.9739849569829494, 0.9689249393722305, 0.970088875290393, 0.9705742032607407, 0.9729016931453687, 0.976046370512338, 0.969851355512636, 0.9714893456863396, 0.971188697196761]
# MAE_test: [7.790115390248593, 8.717689306130852, 8.595232432862822, 10.284834077719998, 10.34238779972696, 8.32170344820367, 8.20787913643172, 8.477921775659158, 9.546749286860571, 8.564573017497638, 9.811760811779205, 9.514669455663356, 8.75338154558961, 8.402102521906098, 8.592568730732463, 8.109803086828311, 8.92037993491483, 9.321940809025595, 9.482036720379933, 7.9832632381153035]
# RMSE_test: [11.605921618987654, 13.211425957569741, 11.998909477380446, 17.026212086760232, 17.38128300252023, 12.609252077352656, 14.9084665221487, 13.055332729772983, 16.17580366084525, 12.537863212486142, 13.776304098681134, 14.340024883127466, 14.235163592993315, 14.489037910296329, 14.344902498909168, 12.868050758138617, 12.960773036850679, 14.35376978915374, 14.212709002649673, 12.614692728007183]

# %%
#Predict Q values
# %cd /content/drive/MyDrive/Colab Notebooks/EMGNN/Q_model/script
# !pip install torch-scatter
# !pip install torch_geometric
# !pip install torch-cluster
# !pip install ase
# !pip install torch-sparse
# !pip install rdkit

! python test.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/EMGNN/Q_model/script
# Requirement already satisfied: torch-scatter in /usr/local/lib/python3.11/dist-packages (2.1.2)
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.11/dist-packages (2.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.4.26)
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.11/dist-packages (1.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from torch-cluster) (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy->torch-cluster) (2.0.2)
# Requirement already satisfied: ase in /usr/local/lib/python3.11/dist-packages (3.25.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from ase) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from ase) (1.15.3)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.11/dist-packages (from ase) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.4->ase) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase) (1.17.0)
# Requirement already satisfied: torch-sparse in /usr/local/lib/python3.11/dist-packages (0.6.18)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from torch-sparse) (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy->torch-sparse) (2.0.2)
# Collecting rdkit
#   Downloading rdkit-2025.3.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# Downloading rdkit-2025.3.2-cp311-cp311-manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 63.9 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.3.2
# fix seed: 2021
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/EMGNN/Q_model/script/test.py", line 114, in <module>
#     checkpoint = torch.load(checkpoint_path, map_location=device)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 1425, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 751, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 732, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoints/finetune/qm9/qm9/ddec_charges/778Q1mdn_checkpoint_best'

# %%
# Multi-objective optimization
# %cd /content/drive/MyDrive/Colab Notebooks/EMGNN/Multi_objective_optimization

! python MTO.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/EMGNN/Multi_objective_optimization
# Requirement already satisfied: rdkit in /usr/local/lib/python3.11/dist-packages (2025.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# /content/drive/MyDrive/Colab Notebooks/EMGNN/Multi_objective_optimization/MTO.py:19: RuntimeWarning: divide by zero encountered in divide
#   PI1 = norm.cdf((1896 - means1) / s1) + norm.cdf((120 - means2) / s2) - (norm.cdf((1800 - means1) / s1)) * (
# /content/drive/MyDrive/Colab Notebooks/EMGNN/Multi_objective_optimization/MTO.py:20: RuntimeWarning: divide by zero encountered in divide
#   norm.cdf((120 - means2) / s2))
# /content/drive/MyDrive/Colab Notebooks/EMGNN/Multi_objective_optimization/MTO.py:22: RuntimeWarning: divide by zero encountered in divide
#   PI2 = norm.cdf((1896 - means1) / s1) + norm.cdf((450 - means2) / s2) - (norm.cdf((1800 - means1) / s1)) * (
# /content/drive/MyDrive/Colab Notebooks/EMGNN/Multi_objective_optimization/MTO.py:23: RuntimeWarning: divide by zero encountered in divide
#   norm.cdf((400 - means2) / s2))
#  Top ： [0.9359492  0.92397061 0.9059409  ... 0.21946528 0.21932318 0.21919028]
# index： [230320 211444 247461 ... 173195 176896  75909]
# 230320                           O=[N+]([O-])N1N=NN2NC=NN21
# 211444         O=[N+]([O-])C1=NN([O-])N=[N+]([O-])N1n1cnnn1
# 247461                             O=[N+]1N=NN1n1nnn2nnnc12
# 26126       [O-][N+]([O-])c1no[n+]([O-])c1C1=[N+]([O-])N=N1
# 216510    O=[N+]([O-])c1nonc1-c1no[n+]([O-])c1-c1no[n+](...
#                                 ...
# 133749        O=[N+]1CC1=NN([O-])C([N+](=O)[O-])[N+]1=NN=N1
# 128771    [N-]=[N+]=Nc1c([N+](=O)[O-])c([N+](=O)[O-])[n+...
# 173195    O=[N+]([O-])OCC1=C([N+](=O)[O-])C(OO)=C([N+](=...
# 176896    N#CC(N(N=c1nc1NN=c1n[n+]1[O-])[N+](=O)[O-])([N...
# 75909                            O=[N+]([O-])C1=NN2N=C2N=N1
# Name: smiles, Length: 2000, dtype: object
